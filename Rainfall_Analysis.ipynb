# %% [markdown]
# <a href="https://colab.research.google.com/github/JustCodeIT199/Rainfall_Analysis/blob/main/Rainfall_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
district_wise_rainfall = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/district wise rainfall normal.csv")
district_wise_rainfall.head()
# Out:
#                  STATE_UT_NAME       DISTRICT    JAN   FEB    MAR    APR  \
# 0  ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3  57.9   65.2  117.0
# 1  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3            ARUNACHAL PRADESH          LOHIT   42.2  80.8  176.4  358.5
# 4            ARUNACHAL PRADESH     EAST SIANG   33.3  79.5  105.9  216.5
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# 0  358.5  295.5  285.0  271.9  354.8  326.0  315.2  250.9  2805.2    165.2
# 1  374.4  457.2  421.3  423.1  455.6  301.2  275.8  128.3  3015.7     69.7
# 2  343.6  503.3  465.4  460.9  454.8  276.1  198.6  100.0  2913.3     48.6
# 3  306.4  447.0  660.1  427.8  313.6  167.1   34.1   29.8  3043.8    123.0
# 4  323.0  738.3  990.9  711.2  568.0  206.9   29.5   31.7  4034.7    112.8
#
#    Mar-May  Jun-Sep  Oct-Dec
# 0    540.7   1207.2    892.1
# ...

# %%
india_rainfall = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/rainfall in india 1901-2015.csv").fillna(0)
india_rainfall.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    Jun-Sep  Oct-Dec
# 0   1696.3    980.3
# 1   2185.9    716.7
# 2   1874.0    690.6
# ...

# %% [markdown]
# # MAXIMUM MINIMUM AND MEAN

# %%
district_wise_rainfall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641 entries, 0 to 640
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   STATE_UT_NAME  641 non-null    object
#  1   DISTRICT       641 non-null    object
#  2   JAN            641 non-null    float64
#  3   FEB            641 non-null    float64
#  4   MAR            641 non-null    float64
#  5   APR            641 non-null    float64
#  6   MAY            641 non-null    float64
#  7   JUN            641 non-null    float64
#  8   JUL            641 non-null    float64
#  9   AUG            641 non-null    float64
#  10  SEP            641 non-null    float64
#  11  OCT            641 non-null    float64
#  12  NOV            641 non-null    float64
#  13  DEC            641 non-null    float64
#  14  ANNUAL         641 non-null    float64
#  15  Jan-Feb        641 non-null    float64
#  16  Mar-May        641 non-null    float64
# ...

# %%
district_wise_rainfall.describe()
# Out:
#               JAN         FEB         MAR         APR         MAY  \
# count  641.000000  641.000000  641.000000  641.000000  641.000000
# mean    18.355070   20.984399   30.034789   45.543214   81.535101
# std     21.082806   27.729596   45.451082   71.556279  111.960390
# min      0.000000    0.000000    0.000000    0.000000    0.900000
# 25%      6.900000    7.000000    7.000000    5.000000   12.100000
# 50%     13.300000   12.300000   12.700000   15.100000   33.900000
# 75%     19.200000   24.100000   33.200000   48.300000   91.900000
# max    144.500000  229.600000  367.900000  554.400000  733.700000
#
#                JUN          JUL          AUG         SEP         OCT  \
# count   641.000000   641.000000   641.000000  641.000000  641.000000
# mean    196.007332   326.033697   291.152262  194.609048   90.446334
# std     196.556284   221.364643   152.647325   99.830540   74.990685
# min       3.800000    11.600000    14.100000    8.600000    3.100000
# ...

# %%
india_rainfall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4116 entries, 0 to 4115
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SUBDIVISION  4116 non-null   object
#  1   YEAR         4116 non-null   int64
#  2   JAN          4116 non-null   float64
#  3   FEB          4116 non-null   float64
#  4   MAR          4116 non-null   float64
#  5   APR          4116 non-null   float64
#  6   MAY          4116 non-null   float64
#  7   JUN          4116 non-null   float64
#  8   JUL          4116 non-null   float64
#  9   AUG          4116 non-null   float64
#  10  SEP          4116 non-null   float64
#  11  OCT          4116 non-null   float64
#  12  NOV          4116 non-null   float64
#  13  DEC          4116 non-null   float64
#  14  ANNUAL       4116 non-null   float64
#  15  Jan-Feb      4116 non-null   float64
#  16  Mar-May      4116 non-null   float64
#  17  Jun-Sep      4116 non-null   float64
# ...

# %%
india_rainfall.describe()
# Out:
#               YEAR          JAN          FEB          MAR          APR  \
# count  4116.000000  4116.000000  4116.000000  4116.000000  4116.000000
# mean   1958.218659    18.938897    21.789431    27.319315    43.085520
# std      33.140898    33.574242    35.901220    46.936787    67.811512
# min    1901.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1930.000000     0.600000     0.600000     1.000000     3.000000
# 50%    1958.000000     6.000000     6.700000     7.800000    15.600000
# 75%    1987.000000    22.125000    26.800000    31.225000    49.825000
# max    2015.000000   583.700000   403.500000   605.600000   595.100000
#
#                MAY          JUN          JUL          AUG          SEP  \
# count  4116.000000  4116.000000  4116.000000  4116.000000  4116.000000
# mean     85.682920   229.954762   346.623834   289.981414   197.074223
# std     123.211711   234.705204   269.690148   188.895403   135.518992
# ...

# %%
subdivision = india_rainfall['SUBDIVISION'].unique()
subdivision
# Out:
# array(['ANDAMAN & NICOBAR ISLANDS', 'ARUNACHAL PRADESH',
#        'ASSAM & MEGHALAYA', 'NAGA MANI MIZO TRIPURA',
#        'SUB HIMALAYAN WEST BENGAL & SIKKIM', 'GANGETIC WEST BENGAL',
#        'ORISSA', 'JHARKHAND', 'BIHAR', 'EAST UTTAR PRADESH',
#        'WEST UTTAR PRADESH', 'UTTARAKHAND', 'HARYANA DELHI & CHANDIGARH',
#        'PUNJAB', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'WEST RAJASTHAN',
#        'EAST RAJASTHAN', 'WEST MADHYA PRADESH', 'EAST MADHYA PRADESH',
#        'GUJARAT REGION', 'SAURASHTRA & KUTCH', 'KONKAN & GOA',
#        'MADHYA MAHARASHTRA', 'MATATHWADA', 'VIDARBHA', 'CHHATTISGARH',
#        'COASTAL ANDHRA PRADESH', 'TELANGANA', 'RAYALSEEMA', 'TAMIL NADU',
#        'COASTAL KARNATAKA', 'NORTH INTERIOR KARNATAKA',
#        'SOUTH INTERIOR KARNATAKA', 'KERALA', 'LAKSHADWEEP'], dtype=object)

# %%
states = district_wise_rainfall['STATE_UT_NAME'].unique()
states
# Out:
# array(['ANDAMAN And NICOBAR ISLANDS', 'ARUNACHAL PRADESH', 'ASSAM',
#        'MEGHALAYA', 'MANIPUR', 'MIZORAM', 'NAGALAND', 'TRIPURA',
#        'WEST BENGAL', 'SIKKIM', 'ORISSA', 'JHARKHAND', 'BIHAR',
#        'UTTAR PRADESH', 'UTTARANCHAL', 'HARYANA', 'CHANDIGARH', 'DELHI',
#        'PUNJAB', 'HIMACHAL', 'JAMMU AND KASHMIR', 'RAJASTHAN',
#        'MADHYA PRADESH', 'GUJARAT', 'DADAR NAGAR HAVELI', 'DAMAN AND DUI',
#        'MAHARASHTRA', 'GOA', 'CHATISGARH', 'ANDHRA PRADESH', 'TAMIL NADU',
#        'PONDICHERRY', 'KARNATAKA', 'KERALA', 'LAKSHADWEEP'], dtype=object)

# %% [markdown]
# # MONTHLY RAINFALL DISTRIBUTED OVER THE YEAR IN EACH STATE
# ## PLACES WITH HIGHEST AND LOWEST RAINFALL

# %%
total_rainfall_in_states = district_wise_rainfall.groupby(['STATE_UT_NAME']).sum()
total_rainfall_in_states['STATE_UT_NAME'] = total_rainfall_in_states.index
total_rainfall_in_states.head()
# Out:
# <ipython-input-75-30e71c6ab333>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_rainfall_in_states = district_wise_rainfall.groupby(['STATE_UT_NAME']).sum()
#                                JAN     FEB     MAR     APR     MAY      JUN  \
# STATE_UT_NAME
# ANDAMAN And NICOBAR ISLANDS  183.7    99.8    92.4   260.9  1076.5   1256.0
# ANDHRA PRADESH               145.4   169.1   232.2   457.1  1121.6   2630.5
# ARUNACHAL PRADESH            859.0  1492.7  2640.3  4402.6  4804.2   7862.1
# ASSAM                        424.8   856.3  2099.6  4894.2  9014.5  12560.0
# BIHAR                        499.1   352.6   375.2   640.9  1963.6   6413.7
#
#                                  JUL      AUG     SEP     OCT     NOV    DEC  \
# STATE_UT_NAME
# ...

# %% [markdown]
# # ANNUAL RAINFALL TREND IN WHOLE COUNTRY
# ## HIGHEST AND LOWEST RAINFALL YEARS

# %%
## ANNUAL RAINFALL TREND FROM HIGHEST TO LOWEST
yearly_rainfall = india_rainfall.groupby(['YEAR']).sum()
yearly_rainfall['rise_fall'] = np.where(yearly_rainfall['ANNUAL'] > yearly_rainfall['ANNUAL'].shift(1), "Rise", "Fall")
yearly_rainfall['YEAR']= yearly_rainfall.index
yearly_rainfall.head()
# Out:
# <ipython-input-76-63c320e9e23b>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   yearly_rainfall = india_rainfall.groupby(['YEAR']).sum()
#          JAN     FEB     MAR     APR     MAY     JUN      JUL      AUG  \
# YEAR
# 1901  1232.7  1417.8   738.4  1623.6  2465.2  6811.3  10192.3  10546.4
# 1902   298.2   290.7   733.3  1602.0  2521.4  5908.7  12290.1   8393.0
# 1903   589.8   502.0   930.2   594.1  2808.3  6019.6  12673.8  10481.9
# 1904   409.4   328.7  1010.8  1449.1  3235.9  8312.0  10919.0   7595.5
# 1905   812.0   716.7  1432.9  1216.4  2675.3  5768.2  10091.0   8637.3
#
#          SEP     OCT     NOV     DEC   ANNUAL  Jan-Feb  Mar-May  Jun-Sep  \
# YEAR
# 1901  4695.4  2579.4  2266.5   378.3  44947.5   2650.3   4827.2  32245.7
# ...

# %%
x1 = yearly_rainfall.sort_values('ANNUAL')
fig = plt.figure(figsize=(20, 8))
ax = plt.xticks(rotation=90)
ax = x1['ANNUAL'].plot.bar(color=['red', 'yellow', 'darkred'], edgecolor = 'black')
ax = plt.title('Highest and Lowest rainfalls')

# %%
ax=india_rainfall.groupby("YEAR").mean()["ANNUAL"]

plt.figure(figsize=(20,8))
ax.plot(marker="o",color="green",markerfacecolor="gold")
plt.grid()
plt.ylabel("Mean of Annual rain;fall all over India",fontsize=15)
plt.xlabel("Year",fontsize=20)
india_rainfall['MA10'] = india_rainfall.groupby('YEAR').mean()['ANNUAL'].rolling(10).mean()
india_rainfall.MA10.plot(color='r',linewidth=4)
# Out:
# <ipython-input-78-b15bde54fff3>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ax=india_rainfall.groupby("YEAR").mean()["ANNUAL"]
# <ipython-input-78-b15bde54fff3>:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   india_rainfall['MA10'] = india_rainfall.groupby('YEAR').mean()['ANNUAL'].rolling(10).mean()
# <Axes: xlabel='Year', ylabel='Mean of Annual rain;fall all over India'>

# %%
india_rainfall.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    Jun-Sep  Oct-Dec  MA10
# 0   1696.3    980.3   NaN
# 1   2185.9    716.7   NaN
# ...

# %%
ms = india_rainfall.groupby('YEAR').mean()
ms
# Out:
# <ipython-input-80-d3527c6df1da>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ms = india_rainfall.groupby('YEAR').mean()
#             JAN        FEB        MAR        APR        MAY         JUN  \
# YEAR
# 1901  35.220000  40.508571  21.097143  46.388571  70.434286  194.608571
# 1902   8.520000   8.305714  20.951429  45.771429  72.040000  168.820000
# 1903  16.851429  14.342857  26.577143  16.974286  80.237143  171.988571
# 1904  11.697143   9.391429  28.880000  41.402857  92.454286  237.485714
# 1905  23.200000  20.477143  40.940000  34.754286  76.437143  164.805714
# ...         ...        ...        ...        ...        ...         ...
# 2011  14.341667  22.769444  27.744444  49.325000  71.561111  241.102778
# 2012  26.722222   9.663889  11.891667  58.241667  50.244444  183.308333
# ...

# %% [markdown]
# ## **BELOW GRAPH SHOWS THE RAINFALL IN INDIA MONTHLY**
#
#
# > <font color='blue'>BLUE</font>: RAINFALL IN JAN TO FEB
#
# > <font color='yellow'>YELLOW</font>: RAINFALL IN MARCH TO MAY
#
# > <font color='green'>GREEN</font>: RAINFALL IN JUNE TO SEPTEMBER
#
# > <font color='red'>RED</font>: RAINFALL IN OCTOBER TO DECEMBER

# %%
india_rainfall[['YEAR','Jan-Feb','Mar-May','Jun-Sep','Oct-Dec']].groupby('YEAR').mean().plot(figsize=(20,10),marker='o')
plt.title("INDIA'S MONTHLY RAINFALL")
plt.xlabel("YEAR",fontsize=10)
plt.ylabel("MEAN SEASONAL RAINFALL IN MM",fontsize=10)
plt.grid()

# %%
india_rainfall[['SUBDIVISION', 'Jan-Feb', 'Mar-May',
       'Jun-Sep', 'Oct-Dec']].groupby("SUBDIVISION").mean().sort_values('Jun-Sep').plot.bar(width=0.5,align='center',figsize=(20,8));

# %% [markdown]
# # **RAINFALL ANALYSIS OF WESTERN GHATS**
# The Western Ghats of India are a very important resource in India. It is home to a whopping 1/3rd of all animal species that exist in the country, thick rainforests and massive mountains. The region is also known for its rich sources of fresh water, with several natural springs and waterfalls that embellish the forests. However, the global climate is changing and we must study its impact of the rainfall pattern in the Western Ghats.
#
#
# 1.  MADHYA MAHARASHTRA
# 2.  KONKAN & GOA
# 3.  COASTAL KARNATAKA
# 4.  SOUTH INTERIOR KARNATAKA
# 5.  KERALA

# %%
# Subdivisions
subdivisions_list = ['MADHYA MAHARASHTRA','KONKAN & GOA','COASTAL KARNATAKA','SOUTH INTERIOR KARNATAKA', 'KERALA']

# region of interest
western_ghats_df = india_rainfall.loc[india_rainfall['SUBDIVISION'].isin(subdivisions_list)]
rest_of_india_df = india_rainfall.loc[india_rainfall['SUBDIVISION'].isin(subdivisions_list)]
display(western_ghats_df)

# Madhya Maharashtra subdivision
madhya_maharashtra_df = western_ghats_df.loc[western_ghats_df['SUBDIVISION'] == 'MADHYA MAHARASHTRA']

# Konkan & Goa subdivision
konkan_goa_df = western_ghats_df.loc[western_ghats_df['SUBDIVISION'] == 'KONKAN & GOA']

# Costal Karnataka subdivision
coastal_karnataka_df = western_ghats_df.loc[western_ghats_df['SUBDIVISION'] == 'COASTAL KARNATAKA']

# South Interior Karnataka subdivision
south_interior_karnataka_df = western_ghats_df.loc[western_ghats_df['SUBDIVISION'] == 'SOUTH INTERIOR KARNATAKA']

# Kerala subdivision
kerala_df = western_ghats_df.loc[western_ghats_df['SUBDIVISION'] == 'KERALA']
# Out:
#        SUBDIVISION  YEAR   JAN   FEB   MAR    APR    MAY     JUN     JUL  \
# 2507  KONKAN & GOA  1901   5.6   0.1   0.4   35.7   19.9   746.1  1075.5
# 2508  KONKAN & GOA  1902   0.3   0.0   0.0    0.4    7.6   428.2   943.6
# 2509  KONKAN & GOA  1903   0.0   0.0   0.1    0.0  201.1   470.5  1298.6
# 2510  KONKAN & GOA  1904   0.0   0.1   6.6    6.3    4.6   975.8   771.7
# 2511  KONKAN & GOA  1905   0.1   0.1   0.0    0.4    8.6   293.7   770.6
# ...            ...   ...   ...   ...   ...    ...    ...     ...     ...
# 3997        KERALA  2011  20.5  45.7  24.1  165.2  124.2   788.5   536.8
# 3998        KERALA  2012   7.4  11.0  21.0  171.1   95.3   430.3   362.6
# 3999        KERALA  2013   3.9  40.1  49.9   49.3  119.3  1042.7   830.2
# 4000        KERALA  2014   4.6  10.3  17.9   95.7  251.0   454.4   677.8
# 4001        KERALA  2015   3.1   5.8  50.1  214.1  201.8   563.6   406.0
#
#         AUG    SEP    OCT    NOV   DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  \
# ...

# %%
plt.figure(figsize=(10,10))
plt.plot(madhya_maharashtra_df['YEAR'], madhya_maharashtra_df['ANNUAL'].ewm(span=10, adjust=False).mean())
plt.plot(konkan_goa_df['YEAR'], konkan_goa_df['ANNUAL'].ewm(span=10, adjust=False).mean())
plt.plot(coastal_karnataka_df['YEAR'], coastal_karnataka_df['ANNUAL'].ewm(span=10, adjust=False).mean())
plt.plot(south_interior_karnataka_df['YEAR'], south_interior_karnataka_df['ANNUAL'].ewm(span=10, adjust=False).mean())
plt.plot(kerala_df['YEAR'], kerala_df['ANNUAL'].ewm(span=10, adjust=False).mean())
plt.ylabel("Annual Rainfall (mm)")
plt.xlabel("Year")
plt.legend(['Madhya Maharashtra', 'Konkan & Goa', 'Coastal Karnataka', 'South Interior Karnataka', 'Kerala'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(madhya_maharashtra_df['YEAR'], madhya_maharashtra_df['Jun-Sep'].ewm(span=10, adjust=False).mean())
plt.plot(konkan_goa_df['YEAR'], konkan_goa_df['Jun-Sep'].ewm(span=10, adjust=False).mean())
plt.plot(coastal_karnataka_df['YEAR'], coastal_karnataka_df['Jun-Sep'].ewm(span=10, adjust=False).mean())
plt.plot(south_interior_karnataka_df['YEAR'], south_interior_karnataka_df['Jun-Sep'].ewm(span=10, adjust=False).mean())
plt.plot(kerala_df['YEAR'], kerala_df['Jun-Sep'].ewm(span=10, adjust=False).mean())
plt.ylabel("Rainfall in June-Sep (mm)")
plt.xlabel("Year")
plt.legend(['Madhya Maharashtra', 'Konkan & Goa', 'Coastal Karnataka', 'South Interior Karnataka', 'Kerala'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(madhya_maharashtra_df['YEAR'], madhya_maharashtra_df['Oct-Dec'].ewm(span=10, adjust=False).mean())
plt.plot(konkan_goa_df['YEAR'], konkan_goa_df['Oct-Dec'].ewm(span=10, adjust=False).mean())
plt.plot(coastal_karnataka_df['YEAR'], coastal_karnataka_df['Oct-Dec'].ewm(span=10, adjust=False).mean())
plt.plot(south_interior_karnataka_df['YEAR'], south_interior_karnataka_df['Oct-Dec'].ewm(span=10, adjust=False).mean())
plt.plot(kerala_df['YEAR'], kerala_df['Oct-Dec'].ewm(span=10, adjust=False).mean())
plt.ylabel("Rainfall in Oct-Dec (mm)")
plt.xlabel("Year")
plt.legend(['Madhya Maharashtra', 'Konkan & Goa', 'Coastal Karnataka', 'South Interior Karnataka', 'Kerala'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(madhya_maharashtra_df['YEAR'], madhya_maharashtra_df['Mar-May'].ewm(span=10, adjust=False).mean())
plt.plot(konkan_goa_df['YEAR'], konkan_goa_df['Mar-May'].ewm(span=10, adjust=False).mean())
plt.plot(coastal_karnataka_df['YEAR'], coastal_karnataka_df['Mar-May'].ewm(span=10, adjust=False).mean())
plt.plot(south_interior_karnataka_df['YEAR'], south_interior_karnataka_df['Mar-May'].ewm(span=10, adjust=False).mean())
plt.plot(kerala_df['YEAR'], kerala_df['Mar-May'].ewm(span=10, adjust=False).mean())
plt.ylabel("Rainfall in March-May (mm)")
plt.xlabel("Year")
plt.legend(['Madhya Maharashtra', 'Konkan & Goa', 'Coastal Karnataka', 'South Interior Karnataka', 'Kerala'], loc='upper left')
plt.show()

# %% [markdown]
# *ANNUAL RAINFALL PATTERN IN ENTIRE WESTERN GHATS*

# %%
western_ghats_yearly_df = western_ghats_df.groupby('YEAR').mean().reset_index()

plt.figure(figsize=(10,10))
plt.plot(western_ghats_yearly_df['YEAR'], western_ghats_yearly_df['ANNUAL'].ewm(span=20, adjust=False).mean())
plt.ylabel("Annual Rainfall in Western Ghats (mm)")
plt.xlabel("Year")
plt.show()
# Out:
# <ipython-input-88-efa1c4f5a7d9>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   western_ghats_yearly_df = western_ghats_df.groupby('YEAR').mean().reset_index()

# %% [markdown]
# # **ARUNACHAL PRADESH RAINFALL ANALYSIS**

# %%
ARUNCHALPRADESH=district_wise_rainfall[district_wise_rainfall.STATE_UT_NAME == 'ARUNACHAL PRADESH']
ARUNCHALPRADESH
# Out:
#         STATE_UT_NAME       DISTRICT   JAN    FEB    MAR    APR    MAY    JUN  \
# 3   ARUNACHAL PRADESH          LOHIT  42.2   80.8  176.4  358.5  306.4  447.0
# 4   ARUNACHAL PRADESH     EAST SIANG  33.3   79.5  105.9  216.5  323.0  738.3
# 5   ARUNACHAL PRADESH  SUBANSIRI F.D  28.0   48.3   85.3  101.5  140.5  228.4
# 6   ARUNACHAL PRADESH          TIRAP  42.2   72.7  141.0  316.9  328.7  614.7
# 7   ARUNACHAL PRADESH  ANJAW (LOHIT)  42.2   80.8  176.4  358.5  306.4  447.0
# 8   ARUNACHAL PRADESH   LOWER DIBANG  83.7  153.9  303.5  383.6  268.0  374.2
# 9   ARUNACHAL PRADESH      CHANGLANG  70.3  170.9  367.9  554.4  334.2  526.2
# 10  ARUNACHAL PRADESH     PAPUM PARE  33.5   67.8  106.1  226.9  453.0  640.5
# 11  ARUNACHAL PRADESH  LOW SUBANSIRI  97.5  109.3   92.4  204.3  266.2  284.1
# 12  ARUNACHAL PRADESH    UPPER SIANG  74.3  176.7  362.6  397.5  408.7  801.9
# 13  ARUNACHAL PRADESH     WEST SIANG  26.0   66.7   76.8  229.2  239.5  416.6
# ...

# %%
plt.figure(figsize=(25,10))
sns.barplot(data=ARUNCHALPRADESH,x="DISTRICT",y="ANNUAL")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # **KERALA RAINFALL ANALYSIS**

# %%
KERALA=district_wise_rainfall[district_wise_rainfall.STATE_UT_NAME == 'KERALA']
KERALA
# Out:
#     STATE_UT_NAME        DISTRICT   JAN   FEB   MAR    APR    MAY    JUN  \
# 626        KERALA       ALAPPUZHA  17.5  27.9  45.1  134.0  298.7  593.0
# 627        KERALA          CANNUR   2.5   2.0   7.6   57.9  235.0  852.4
# 628        KERALA       ERNAKULAM  13.2  18.8  31.2  112.0  300.4  696.4
# 629        KERALA        KOTTAYAM  13.0  24.9  42.3  136.1  281.8  649.1
# 630        KERALA       KOZHIKODE   2.3   3.9  15.1   80.9  256.6  895.8
# 631        KERALA      MALAPPURAM   1.7   3.9  12.7   86.8  221.3  660.9
# 632        KERALA        PALAKKAD   2.9   6.5  22.5   98.7  158.7  464.3
# 633        KERALA          KOLLAM  17.5  33.7  62.6  158.5  248.5  457.7
# 634        KERALA        THRISSUR   3.4   7.5  17.0   79.2  289.1  707.4
# 635        KERALA   THIRUVANANTHA  19.3  21.1  35.5  116.7  216.6  338.7
# 636        KERALA          IDUKKI  13.4  22.1  43.6  150.4  232.6  651.6
# 637        KERALA        KASARGOD   2.3   1.0   8.4   46.9  217.6  999.6
# ...

# %%
plt.figure(figsize=(25,10))
sns.barplot(data=KERALA,x="DISTRICT",y="ANNUAL")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # **RAJASTHAN RAINFALL ANALYSIS**

# %%
RAJASTHAN=district_wise_rainfall[district_wise_rainfall.STATE_UT_NAME == 'RAJASTHAN']
RAJASTHAN
# Out:
#     STATE_UT_NAME        DISTRICT  JAN   FEB  MAR  APR   MAY    JUN    JUL  \
# 370     RAJASTHAN          BARMER  1.2   1.7  2.3  3.2   9.1   27.4   88.6
# 371     RAJASTHAN         BIKANER  4.1   7.8  5.7  4.1  14.3   29.2   85.7
# 372     RAJASTHAN           CHURU  6.2   7.4  6.3  4.9  16.4   37.7  126.6
# 373     RAJASTHAN   SRI GANGANAGA  6.0   8.0  9.3  7.0  11.6   25.5   79.3
# 374     RAJASTHAN       JAISALMER  1.7   2.9  2.2  3.8   6.6   19.4   59.3
# 375     RAJASTHAN          JALORE  1.8   1.1  2.6  1.4   8.2   34.5  161.1
# 376     RAJASTHAN         JODHPUR  2.9   3.1  2.7  5.2  11.1   27.9  109.5
# 377     RAJASTHAN          NAGAUR  4.1   5.5  2.7  4.7  15.3   42.5  142.6
# 378     RAJASTHAN            PALI  3.7   2.5  2.9  2.7   9.5   41.9  177.3
# 379     RAJASTHAN     HANUMANGARH  7.5   8.6  5.7  4.9  13.0   32.2  103.4
# 380     RAJASTHAN           AJMER  3.7   2.0  2.1  2.2   8.9   43.6  171.0
# ...

# %%
plt.figure(figsize=(25,10))
sns.barplot(data=RAJASTHAN,x="DISTRICT",y="ANNUAL")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # **TAMIL NADU RAINFALL ANALYSIS**

# %%
TAMILNADU=district_wise_rainfall[district_wise_rainfall.STATE_UT_NAME == 'TAMIL NADU']
TAMILNADU
# Out:
#     STATE_UT_NAME       DISTRICT   JAN   FEB   MAR    APR    MAY    JUN  \
# 560    TAMIL NADU        VELLORE   8.1   6.8   9.2   22.3   75.0   65.9
# 561    TAMIL NADU     COIMBATORE   8.1  12.2  17.2   53.4   79.7   32.9
# 562    TAMIL NADU     DHARMAPURI   8.0  10.2  15.9   41.7  102.8   53.6
# 563    TAMIL NADU    KANYAKUMARI  18.4  22.0  42.5  104.3  141.5  186.1
# 564    TAMIL NADU        CHENNAI  22.1  14.6   3.0   12.0   43.5   64.1
# 565    TAMIL NADU        MADURAI  13.6  14.5  20.6   57.8   66.4   48.7
# 566    TAMIL NADU       NILGIRIS  23.1  26.2  35.6   82.4  117.3  169.8
# 567    TAMIL NADU  RAMANATHAPURA  33.0  18.3  23.5   53.0   39.0   16.9
# 568    TAMIL NADU          SALEM   8.5   7.5  16.0   54.0  100.8   65.1
# 569    TAMIL NADU      THANJAVUR  26.9  15.4  17.3   30.5   54.3   39.8
# 570    TAMIL NADU  TIRUCHIRAPPAL  13.6   9.1  11.8   38.4   59.7   31.5
# 571    TAMIL NADU    TIRUNELVELI  35.4  33.9  48.1   70.4   47.7   37.9
# ...

# %%
plt.figure(figsize=(25,10))
sns.barplot(data=TAMILNADU,x="DISTRICT",y="ANNUAL")
plt.xticks(rotation=90)
plt.show()

# %%
india_rainfall.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    Jun-Sep  Oct-Dec  MA10
# 0   1696.3    980.3   NaN
# 1   2185.9    716.7   NaN
# ...

# %%
district_wise_rainfall.head()
# Out:
#                  STATE_UT_NAME       DISTRICT    JAN   FEB    MAR    APR  \
# 0  ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3  57.9   65.2  117.0
# 1  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3            ARUNACHAL PRADESH          LOHIT   42.2  80.8  176.4  358.5
# 4            ARUNACHAL PRADESH     EAST SIANG   33.3  79.5  105.9  216.5
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# 0  358.5  295.5  285.0  271.9  354.8  326.0  315.2  250.9  2805.2    165.2
# 1  374.4  457.2  421.3  423.1  455.6  301.2  275.8  128.3  3015.7     69.7
# 2  343.6  503.3  465.4  460.9  454.8  276.1  198.6  100.0  2913.3     48.6
# 3  306.4  447.0  660.1  427.8  313.6  167.1   34.1   29.8  3043.8    123.0
# 4  323.0  738.3  990.9  711.2  568.0  206.9   29.5   31.7  4034.7    112.8
#
#    Mar-May  Jun-Sep  Oct-Dec
# 0    540.7   1207.2    892.1
# ...

# %%
X = india_rainfall.drop("MA10", axis = 1 )

# %%
X.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    Jun-Sep  Oct-Dec
# 0   1696.3    980.3
# 1   2185.9    716.7
# 2   1874.0    690.6
# ...

# %%
X = india_rainfall.drop("ANNUAL", axis = 1 )
X.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  Jan-Feb  Mar-May  Jun-Sep  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6    136.3    560.3   1696.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5    159.8    458.3   2185.9
# 2  728.4  326.7  339.0  181.2  284.4  225.0    156.7    236.1   1874.0
# 3  502.0  160.1  820.4  222.2  308.7   40.1     24.1    506.9   1977.6
# 4  368.7  330.5  297.0  260.7   25.4  344.7      1.3    309.7   1624.9
#
#    Oct-Dec  MA10
# 0    980.3   NaN
# 1    716.7   NaN
# 2    690.6   NaN
# ...

# %%
y = india_rainfall['ANNUAL']
y.head()
# Out:
# 0    3373.2
# 1    3520.7
# 2    2957.4
# 3    3079.6
# 4    2566.7
# Name: ANNUAL, dtype: float64

# %%
from sklearn.model_selection  import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3292, 19), (824, 19), (3292,), (824,))

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer


categorical_features = ["Jan-Feb","Mar-May", "Jun-Sep","Oct-Dec"]
one_hot = OneHotEncoder()
transformer = ColumnTransformer([("one_hot",
                                  one_hot,
                                  categorical_features)],
                                remainder = "passthrough")

# %%
#from sklearn.compose import ColumnTransformer
#transformed_X = transformer.fit_transform(X)
#transformed_X

# %%
alternate = pd.get_dummies(india_rainfall[["Jan-Feb","Mar-May", "Jun-Sep","Oct-Dec"]])
alternate
# Out:
#       Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# 0       136.3    560.3   1696.3    980.3
# 1       159.8    458.3   2185.9    716.7
# 2       156.7    236.1   1874.0    690.6
# 3        24.1    506.9   1977.6    571.0
# 4         1.3    309.7   1624.9    630.8
# ...       ...      ...      ...      ...
# 4111      7.9    196.2   1013.0    316.6
# 4112     19.3     99.6   1119.5    167.1
# 4113     60.6    131.1   1057.0    177.6
# 4114     69.3     76.7    958.5    290.5
# 4115      2.7    223.9    860.9    555.4
#
# [4116 rows x 4 columns]

# %%
# !pip install scikit-learn
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.9958697392806451

# %% [markdown]
# refit model

# %%
np.random.seed(42)
X_train, X_test, y_train, y_test = train_test_split(alternate, y, test_size = 0.2)
model.fit(X_train, y_train)

# %%
model.score(X_test, y_test)
# Out:
# 0.9958697392806451

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense
import keras

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/district wise rainfall normal.csv")
df.head(10)
# Out:
#                  STATE_UT_NAME       DISTRICT    JAN    FEB    MAR    APR  \
# 0  ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3   57.9   65.2  117.0
# 1  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7   26.0   18.6   90.5
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7   15.9    8.6   53.4
# 3            ARUNACHAL PRADESH          LOHIT   42.2   80.8  176.4  358.5
# 4            ARUNACHAL PRADESH     EAST SIANG   33.3   79.5  105.9  216.5
# 5            ARUNACHAL PRADESH  SUBANSIRI F.D   28.0   48.3   85.3  101.5
# 6            ARUNACHAL PRADESH          TIRAP   42.2   72.7  141.0  316.9
# 7            ARUNACHAL PRADESH  ANJAW (LOHIT)   42.2   80.8  176.4  358.5
# 8            ARUNACHAL PRADESH   LOWER DIBANG   83.7  153.9  303.5  383.6
# 9            ARUNACHAL PRADESH      CHANGLANG   70.3  170.9  367.9  554.4
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# 0  358.5  295.5  285.0  271.9  354.8  326.0  315.2  250.9  2805.2    165.2
# ...

# %%
# @title Correlation matrix of monthly rainfall

import matplotlib.pyplot as plt
import seaborn as sns

corr = df.corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns)
_ = plt.title('Correlation Matrix of Monthly Rainfall')
# Out:
# <ipython-input-130-dede7438ce2c>:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
